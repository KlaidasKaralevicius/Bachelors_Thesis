# %%
from ultralytics import YOLO
model = YOLO("weights/yolo26n.pt")  # yolo26[n-s-m-l-x].pt yolo26[n-s-m-l-x]-trained.pt

# %%
results = model.val(
    data='new_dataset.yaml',
    split='val',
    plots=True,
    project='new_test',
    name='nano', # nano, small, medium, large, xlarge | nano-trained small-trained medium-trained large-trained xlarge-trained
    seed=226,
    exist_ok=True,
    device=0
)
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 11913MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4920.3±2093.3 MB/s, size: 2786.6 KB)
# val: Scanning /home/kaemri/Semester/bachelors/Bachelors_Thesis/new_data_test/labels/val.cache... 8 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 8/8 3.7Mit/s 0.0s
# val: /home/kaemri/Semester/bachelors/Bachelors_Thesis/new_data_test/images/val/20260329_192408.jpg: corrupt JPEG restored and saved
# val: /home/kaemri/Semester/bachelors/Bachelors_Thesis/new_data_test/images/val/20260329_192949.jpg: corrupt JPEG restored and saved
# val: /home/kaemri/Semester/bachelors/Bachelors_Thesis/new_data_test/images/val/20260329_193336.jpg: corrupt JPEG restored and saved
# val: /home/kaemri/Semester/bachelors/Bachelors_Thesis/new_data_test/images/val/20260402_205908.jpg: corrupt JPEG restored and saved
# ...

# %%
results = model.predict(
    source="../new_data_test/images",
    save=True,
    save_txt=False,
    project='new_test',
    name='medium-trained',
    seed=226,
    exist_ok=True,
    device=0
)
# Out:
# image 1/8 /home/kaemri/Semester/bachelors/Bachelors_Thesis/code/../new_data_test/images/20260329_192408.jpg: 288x640 2 ladles, 1 spatula, 1 frying pan, 1 sauce pan, 1 pan lid, 1 grater, 10.1ms
# image 2/8 /home/kaemri/Semester/bachelors/Bachelors_Thesis/code/../new_data_test/images/20260329_192949.jpg: 288x640 1 cup, 1 sauce pan, 1 grater, 9.4ms
# image 3/8 /home/kaemri/Semester/bachelors/Bachelors_Thesis/code/../new_data_test/images/20260329_193336.jpg: 288x640 2 forks, 1 knife, 1 spatula, 1 bowl, 8.3ms
# image 4/8 /home/kaemri/Semester/bachelors/Bachelors_Thesis/code/../new_data_test/images/20260402_205400.jpg: 288x640 1 knife, 1 ladle, 1 cup, 1 colander, 2 graters, 8.9ms
# image 5/8 /home/kaemri/Semester/bachelors/Bachelors_Thesis/code/../new_data_test/images/20260402_205717.jpg: 288x640 3 ladles, 1 colander, 3 graters, 1 cutting board, 8.4ms
# ...
